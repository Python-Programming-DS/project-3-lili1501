# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Load and Read Data

# %%
df = pd.read_csv("new_train_EGN5442.csv")
df.head()
# Out:
#    Unnamed: 0  y      x2      x3  x5  x9  x10  x11  x12  x13  ... x23   x24  \
# 0           0  1  #54359  Female  50   5    5    5    4    3  ...  21  12.0
# 1           1  1  #84649  Female  44   1    1    1    1    3  ...   0   0.0
# 2           2  0  #59015  Female  72   3    1    5    5    3  ...   0   8.0
# 3           3  0  #99990  Female  38   1    3    1    3    5  ...   0   0.0
# 4           4  1  #83569    Male  37   5    5    5    5    2  ...   0   0.0
#
#    x25  x26  x28       x29  x30       x31  x4  x6
# 0  D_C   Bt    1   (192&&)  NaN  2.380952   4  50
# 1  L_C   Bt    1  (1034&&)  NaN       inf   4  44
# 2  L_C   Bt    3  (1452&&)  NaN       inf   4  72
# 3  L_C   PT    3   (916&&)  NaN       inf   4  38
# 4  L_C   Bt    1   (390&&)  NaN       inf   4  37
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104722 entries, 0 to 104721
# Data columns (total 29 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  104722 non-null  int64
#  1   y           104722 non-null  int64
#  2   x2          104722 non-null  object
#  3   x3          104722 non-null  object
#  4   x5          104722 non-null  int64
#  5   x9          104722 non-null  int64
#  6   x10         104722 non-null  int64
#  7   x11         104722 non-null  int64
#  8   x12         104722 non-null  int64
#  9   x13         104722 non-null  int64
#  10  x14         104722 non-null  object
#  11  x15         104722 non-null  int64
#  12  x16         104722 non-null  int64
#  13  x17         104722 non-null  int64
#  14  x18         104722 non-null  int64
#  15  x19         104722 non-null  int64
#  16  x20         104722 non-null  int64
#  17  x21         104722 non-null  int64
#  18  x22         104722 non-null  int64
#  19  x23         104722 non-null  int64
#  20  x24         104410 non-null  float64
#  21  x25         104722 non-null  object
#  22  x26         104722 non-null  object
#  23  x28         104722 non-null  int64
#  24  x29         104722 non-null  object
#  25  x30         0 non-null       float64
#  26  x31         104722 non-null  float64
#  27  x4          104722 non-null  int64
#  28  x6          104722 non-null  int64
# dtypes: float64(3), int64(20), object(6)
# memory usage: 23.2+ MB

# %%
df.describe(include='all')
# Out:
# /opt/miniconda3/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:4671: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
#            Unnamed: 0              y      x2      x3             x5  \
# count   104722.000000  104722.000000  104722  104722  104722.000000
# unique            NaN            NaN  103904       2            NaN
# top               NaN            NaN  #42598  Female            NaN
# freq              NaN            NaN       2   53142            NaN
# mean     52360.500000       0.431380     NaN     NaN      39.189273
# std      30230.781782       0.495271     NaN     NaN      15.208026
# min          0.000000       0.000000     NaN     NaN       7.000000
# 25%      26180.250000       0.000000     NaN     NaN      27.000000
# 50%      52360.500000       0.000000     NaN     NaN      40.000000
# 75%      78540.750000       1.000000     NaN     NaN      51.000000
# max     104721.000000       1.000000     NaN     NaN      85.000000
#
#                    x9            x10            x11            x12  \
# count   104722.000000  104722.000000  104722.000000  104722.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         2.728892       3.062986       2.755591       2.977187
# std          1.326905       1.525021       1.398492       1.277116
# min          0.000000       0.000000       0.000000       0.000000
# 25%          2.000000       2.000000       2.000000       2.000000
# 50%          3.000000       3.000000       3.000000       3.000000
# 75%          4.000000       4.000000       4.000000       4.000000
# max          5.000000       5.000000       5.000000       5.000000
#
#                   x13  ...            x23            x24     x25     x26  \
# count   104722.000000  ...  104722.000000  104410.000000  104722  104722
# unique            NaN  ...            NaN            NaN       2       2
# top               NaN  ...            NaN            NaN     L_C      Bt
# freq              NaN  ...            NaN            NaN   85596   71926
# mean         3.201419  ...      14.818405      15.188909     NaN     NaN
# std          1.329776  ...      38.305687      38.785838     NaN     NaN
# min          0.000000  ...       0.000000       0.000000     NaN     NaN
# 25%          2.000000  ...       0.000000       0.000000     NaN     NaN
# 50%          3.000000  ...       0.000000       0.000000     NaN     NaN
# 75%          4.000000  ...      12.000000      13.000000     NaN     NaN
# max          5.000000  ...    1592.000000    1584.000000     NaN     NaN
#
#                   x28      x29  x30           x31        x4             x6
# count   104722.000000   104722  0.0  1.047220e+05  104722.0  104722.000000
# unique            NaN     3802  NaN           NaN       NaN            NaN
# top               NaN  (337&&)  NaN           NaN       NaN            NaN
# freq              NaN      667  NaN           NaN       NaN            NaN
# mean         1.976089      NaN  NaN           inf       4.0      39.189273
# std          0.962887      NaN  NaN           NaN       0.0      15.208026
# min          1.000000      NaN  NaN  9.668508e-03       4.0       7.000000
# 25%          1.000000      NaN  NaN  3.000000e+00       4.0      27.000000
# 50%          2.000000      NaN  NaN           NaN       4.0      40.000000
# 75%          3.000000      NaN  NaN           NaN       4.0      51.000000
# max          3.000000      NaN  NaN           inf       4.0      85.000000
#
# [11 rows x 29 columns]

# %% [markdown]
# ##### Remove any unwanted characters present under any column

# %%
df = df.replace(r'[^A-Za-z0-9\.\-]', '', regex=True)
df.head()
# Out:
#    Unnamed: 0  y     x2      x3  x5  x9  x10  x11  x12  x13  ... x23   x24  \
# 0           0  1  54359  Female  50   5    5    5    4    3  ...  21  12.0
# 1           1  1  84649  Female  44   1    1    1    1    3  ...   0   0.0
# 2           2  0  59015  Female  72   3    1    5    5    3  ...   0   8.0
# 3           3  0  99990  Female  38   1    3    1    3    5  ...   0   0.0
# 4           4  1  83569    Male  37   5    5    5    5    2  ...   0   0.0
#
#    x25  x26  x28   x29  x30       x31  x4  x6
# 0   DC   Bt    1   192  NaN  2.380952   4  50
# 1   LC   Bt    1  1034  NaN       inf   4  44
# 2   LC   Bt    3  1452  NaN       inf   4  72
# 3   LC   PT    3   916  NaN       inf   4  38
# 4   LC   Bt    1   390  NaN       inf   4  37
#
# [5 rows x 29 columns]

# %% [markdown]
# ##### Further removing unwanted columns such Unnamed: or any fully empty cols that are present

# %%
df = df.drop(columns=['Unnamed: 0','x30'])
df.head()
# Out:
#    y     x2      x3  x5  x9  x10  x11  x12  x13 x14  ...  x22  x23   x24  x25  \
# 0  1  54359  Female  50   5    5    5    4    3   5  ...    3   21  12.0   DC
# 1  1  84649  Female  44   1    1    1    1    3   3  ...    2    0   0.0   LC
# 2  0  59015  Female  72   3    1    5    5    3   2  ...    2    0   8.0   LC
# 3  0  99990  Female  38   1    3    1    3    5   1  ...    5    0   0.0   LC
# 4  1  83569    Male  37   5    5    5    5    2   5  ...    5    0   0.0   LC
#
#    x26  x28   x29       x31  x4  x6
# 0   Bt    1   192  2.380952   4  50
# 1   Bt    1  1034       inf   4  44
# 2   Bt    3  1452       inf   4  72
# 3   PT    3   916       inf   4  38
# 4   Bt    1   390       inf   4  37
#
# [5 rows x 27 columns]

# %%
before = df.shape
print(before)
# Out:
# (104722, 27)

# %% [markdown]
# ##### Removing duplicate rows if any

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (103904, 27)

# %% [markdown]
# ##### To handle missing values in some rows

# %% [markdown]
# ##### if it's numeric column fill nan values with median

# %%
for col in df.select_dtypes(include=['float','int']).columns:
    df[col] = df[col].fillna(df[col].median())

# %% [markdown]
# ##### if it's categorical column fill nan values with mode

# %%
for col in df.select_dtypes(include=['object']).columns:
    df[col] = df[col].fillna(df[col].mode()[0])

# %% [markdown]
# ##### Looking at the object cols from info

# %%
df[['x2','x3','x14','x25','x26','x29']].head()
# Out:
#       x2      x3 x14 x25 x26   x29
# 0  54359  Female   5  DC  Bt   192
# 1  84649  Female   3  LC  Bt  1034
# 2  59015  Female   2  LC  Bt  1452
# 3  99990  Female   1  LC  PT   916
# 4  83569    Male   5  LC  Bt   390

# %% [markdown]
# ##### Using one hot encoding label for categorical column x3, x25, x26

# %%
df = pd.get_dummies(df, columns=['x3', 'x25', 'x26'], drop_first=True)
df.head()
# Out:
#    y     x2  x5  x9  x10  x11  x12  x13 x14  x15  ...  x23   x24  x28   x29  \
# 0  1  54359  50   5    5    5    4    3   5    3  ...   21  12.0    1   192
# 1  1  84649  44   1    1    1    1    3   3    1  ...    0   0.0    1  1034
# 2  0  59015  72   3    1    5    5    3   2    2  ...    0   8.0    3  1452
# 3  0  99990  38   1    3    1    3    5   1    5  ...    0   0.0    3   916
# 4  1  83569  37   5    5    5    5    2   5    5  ...    0   0.0    1   390
#
#         x31  x4  x6  x3_Male  x25_LC  x26_PT
# 0  2.380952   4  50    False   False   False
# 1       inf   4  44    False    True   False
# 2       inf   4  72    False    True   False
# 3       inf   4  38    False    True    True
# 4       inf   4  37     True    True   False
#
# [5 rows x 27 columns]

# %% [markdown]
# ##### Converting the numeric looking col to numeric

# %%
df['x2'] = pd.to_numeric(df['x2'], errors='coerce')
df['x29'] = pd.to_numeric(df['x29'], errors='coerce')
df['x14'] = pd.to_numeric(df['x14'], errors='coerce')
df.head()
# Out:
#    y     x2  x5  x9  x10  x11  x12  x13  x14  x15  ...  x23   x24  x28   x29  \
# 0  1  54359  50   5    5    5    4    3  5.0    3  ...   21  12.0    1   192
# 1  1  84649  44   1    1    1    1    3  3.0    1  ...    0   0.0    1  1034
# 2  0  59015  72   3    1    5    5    3  2.0    2  ...    0   8.0    3  1452
# 3  0  99990  38   1    3    1    3    5  1.0    5  ...    0   0.0    3   916
# 4  1  83569  37   5    5    5    5    2  5.0    5  ...    0   0.0    1   390
#
#         x31  x4  x6  x3_Male  x25_LC  x26_PT
# 0  2.380952   4  50    False   False   False
# 1       inf   4  44    False    True   False
# 2       inf   4  72    False    True   False
# 3       inf   4  38    False    True    True
# 4       inf   4  37     True    True   False
#
# [5 rows x 27 columns]

# %% [markdown]
# ##### To check for highly correlated pairs

# %%
corr_matrix = df.corr().abs()
high_corr_pairs = np.where(corr_matrix > 0.8)

high_corr = [
    (df.columns[i], df.columns[j], corr_matrix.iloc[i, j])
    for i, j in zip(*high_corr_pairs)
    if i != j and i < j
]

high_corr
# Out:
# [('x5', 'x6', np.float64(1.0)), ('x23', 'x24', np.float64(0.9602470986642704))]

# %% [markdown]
# ##### Checking x5,x6,x23 and x24

# %%
df[['x5','x6','x23','x24']]
# Out:
#         x5  x6  x23   x24
# 0       50  50   21  12.0
# 1       44  44    0   0.0
# 2       72  72    0   8.0
# 3       38  38    0   0.0
# 4       37  37    0   0.0
# ...     ..  ..  ...   ...
# 104717  27  27   70  38.0
# 104718  62  62    6  33.0
# 104719  45  45   16   7.0
# 104720  57  57    0   0.0
# 104721  59  59   56  33.0
#
# [103904 rows x 4 columns]

# %% [markdown]
# ##### x5 and x6 are have perfect correlation, they both are similar. One can be dropped. Similary on an overall level both x23 and x24 have high correlation and one it can be dropped

# %%
df.drop(columns=['x6','x24'],inplace=True)
df.head()
# Out:
#    y     x2  x5  x9  x10  x11  x12  x13  x14  x15  ...  x21  x22  x23  x28  \
# 0  1  54359  50   5    5    5    4    3  5.0    3  ...    4    3   21    1
# 1  1  84649  44   1    1    1    1    3  3.0    1  ...    4    2    0    1
# 2  0  59015  72   3    1    5    5    3  2.0    2  ...    3    2    0    3
# 3  0  99990  38   1    3    1    3    5  1.0    5  ...    4    5    0    3
# 4  1  83569  37   5    5    5    5    2  5.0    5  ...    4    5    0    1
#
#     x29       x31  x4  x3_Male  x25_LC  x26_PT
# 0   192  2.380952   4    False   False   False
# 1  1034       inf   4    False    True   False
# 2  1452       inf   4    False    True   False
# 3   916       inf   4    False    True    True
# 4   390       inf   4     True    True   False
#
# [5 rows x 25 columns]

# %% [markdown]
# ##### Identifying numeric cols

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
num_cols
# Out:
# ['y',
#  'x2',
#  'x5',
#  'x9',
#  'x10',
#  'x11',
#  'x12',
#  'x13',
#  'x14',
#  'x15',
#  'x16',
#  'x17',
#  'x18',
#  'x19',
#  'x20',
#  'x21',
#  'x22',
#  'x23',
#  'x28',
#  'x29',
#  'x31',
#  'x4']

# %% [markdown]
# ##### Filtering continuous cols

# %%
continuous_cols = [col for col in num_cols if df[col].nunique() > 10]
continuous_cols
# Out:
# ['x2', 'x5', 'x23', 'x29', 'x31']

# %%
df.nunique()
# Out:
# y               2
# x2         103904
# x5             75
# x9              6
# x10             6
# x11             6
# x12             6
# x13             6
# x14             5
# x15             6
# x16             6
# x17             6
# x18             6
# x19             5
# x20             6
# x21             6
# x22             6
# x23           446
# x28             3
# x29          3802
# x31          5541
# x4              1
# x3_Male         2
# x25_LC          2
# x26_PT          2
# dtype: int64

# %% [markdown]
# ##### We have total 103904 rows and x2 has 103904 as id col,this feature won't give us much meaningful info while modeling so will drop x2

# %%
df.drop(columns=['x2'],inplace=True)
df.head()
# Out:
#    y  x5  x9  x10  x11  x12  x13  x14  x15  x16  ...  x21  x22  x23  x28  \
# 0  1  50   5    5    5    4    3  5.0    3    3  ...    4    3   21    1
# 1  1  44   1    1    1    1    3  3.0    1    4  ...    4    2    0    1
# 2  0  72   3    1    5    5    3  2.0    2    3  ...    3    2    0    3
# 3  0  38   1    3    1    3    5  1.0    5    5  ...    4    5    0    3
# 4  1  37   5    5    5    5    2  5.0    5    4  ...    4    5    0    1
#
#     x29       x31  x4  x3_Male  x25_LC  x26_PT
# 0   192  2.380952   4    False   False   False
# 1  1034       inf   4    False    True   False
# 2  1452       inf   4    False    True   False
# 3   916       inf   4    False    True    True
# 4   390       inf   4     True    True   False
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Binning the continuos cols to qualtile to understand how y changes across ranges

# %%
qbin_cols =['x5','x23', 'x29', 'x31']
df[qbin_cols].isna().sum()
# Out:
# x5     0
# x23    0
# x29    0
# x31    0
# dtype: int64

# %%
np.isinf(df[['x5','x23','x29','x31']]).sum()
# Out:
# x5         0
# x23        0
# x29        0
# x31    58668
# dtype: int64

# %%
df['x31'] = df['x31'].replace([np.inf, -np.inf], np.nan)
df['x31'] = df['x31'].fillna(df['x31'].median())

# %%
for col in qbin_cols:
    df[col + '_qbin'] = pd.qcut(df[col].rank(method='first'), q=4,labels=[1, 2, 3, 4],duplicates='drop')
    df[col + "_qbin"] = df[col + "_qbin"].astype(int)
df.head()
# Out:
#    y  x5  x9  x10  x11  x12  x13  x14  x15  x16  ...   x29       x31  x4  \
# 0  1  50   5    5    5    4    3  5.0    3    3  ...   192  2.380952   4
# 1  1  44   1    1    1    1    3  3.0    1    4  ...  1034  2.250000   4
# 2  0  72   3    1    5    5    3  2.0    2    3  ...  1452  2.250000   4
# 3  0  38   1    3    1    3    5  1.0    5    5  ...   916  2.250000   4
# 4  1  37   5    5    5    5    2  5.0    5    4  ...   390  2.250000   4
#
#    x3_Male  x25_LC  x26_PT  x5_qbin  x23_qbin  x29_qbin  x31_qbin
# 0    False   False   False        3         4         1         4
# 1    False    True   False        3         1         3         1
# 2    False    True   False        4         1         3         1
# 3    False    True    True        2         1         3         1
# 4     True    True   False        2         1         1         1
#
# [5 rows x 28 columns]

# %%
sns.countplot(x=df['y'])
plt.title("Target Distribution")
plt.show()

# %% [markdown]
# #### Visulaize any null values through heat map

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# ##### Visulaize the continuous column variable for analysis

# %%
cols = ['x5','x23','x29','x31']

plt.figure(figsize=(12, 10))
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

for ax, col in zip(axes.flatten(), cols):
    sns.histplot(df[col], bins=30, kde=True, ax=ax)
    ax.set_title(f"Distribution of {col}")

plt.tight_layout()
plt.show()

# %%
cols = ['x5','x23','x29','x31']

plt.figure(figsize=(12, 10))
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
for ax, col in zip(axes.flatten(), cols):
    sns.barplot(x=col + '_qbin', y='y', data=df, ax= ax)
    ax.set_title(f"Average y Across {col} Bins")
    # ax.tick_params(axis='x', rotation=30)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Correlation Analysis

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df.corr(numeric_only=True), cmap='coolwarm', center=0)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### Save the cleaned data

# %%
df.to_csv('cleaned_new_train_data.csv',index=False)
